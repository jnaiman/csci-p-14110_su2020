# %% [markdown]
# # Generate Simulation data from NASA planet database
#
# This is an optional notebook that generates simulated orbits for planets from the NASA database (and a few extra ones "by hand" too!).

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# A few extra things we'll need in external libraries:

# %%
from convert_kepler_data import convert_kepler_data
from hermite_library import do_hermite, save_hermite_solution_to_file

# %% [markdown]
# Read in database file:

# %%
#planets = pd.read_csv('https://jnaiman.github.io/csci-p-14110_su2020/lesson08/planets_2020.06.17_14.04.11.csv', 
#                     sep=",", comment="#")

planets = pd.read_csv('planets_2020.06.22_10.10.17.csv',sep=",", comment="#")

# %%
planets.head()
# Out:
#    rowid pl_hostname pl_letter     pl_name    pl_discmethod  pl_controvflag  \
# 0      1      11 Com         b    11 Com b  Radial Velocity               0
# 1      2      11 UMi         b    11 UMi b  Radial Velocity               0
# 2      3      14 And         b    14 And b  Radial Velocity               0
# 3      4      14 Her         b    14 Her b  Radial Velocity               0
# 4      5    16 Cyg B         b  16 Cyg B b  Radial Velocity               0
#
#    pl_pnum   pl_orbper  pl_orbpererr1  pl_orbpererr2  ...  st_bmy  st_bmyerr  \
# 0        1   326.03000           0.32          -0.32  ...     NaN        NaN
# 1        1   516.21997           3.20          -3.20  ...     NaN        NaN
# 2        1   185.84000           0.23          -0.23  ...     NaN        NaN
# 3        1  1773.40002           2.50          -2.50  ...   0.537      0.001
# 4        1   798.50000           1.00          -1.00  ...   0.418      0.003
#
#    st_bmylim  st_m1  st_m1err  st_m1lim  st_c1  st_c1err  st_c1lim  st_colorn
# 0        NaN    NaN       NaN       NaN    NaN       NaN       NaN        7.0
# 1        NaN    NaN       NaN       NaN    NaN       NaN       NaN        5.0
# 2        NaN    NaN       NaN       NaN    NaN       NaN       NaN        7.0
# 3        0.0  0.366     0.002       0.0  0.438     0.006       0.0        9.0
# 4        0.0  0.222     0.003       0.0  0.351     0.003       0.0       17.0
#
# [5 rows x 356 columns]

# %%
len(planets)
# Out:
# 4164

# %% [markdown]
# Now we choose systems to simulate.  I'm gonna pick all systems with > 4 planets:

# %%
mask = planets['pl_pnum'] > 5

# %% [markdown]
# Subset dataframe:

# %%
multi_planets = planets[mask]

# %%
multi_planets
# Out:
#       rowid pl_hostname pl_letter       pl_name    pl_discmethod  \
# 370     371    HD 10180         c    HD 10180 c  Radial Velocity
# 371     372    HD 10180         d    HD 10180 d  Radial Velocity
# 372     373    HD 10180         e    HD 10180 e  Radial Velocity
# 373     374    HD 10180         f    HD 10180 f  Radial Velocity
# 374     375    HD 10180         g    HD 10180 g  Radial Velocity
# 375     376    HD 10180         h    HD 10180 h  Radial Velocity
# 684     685   HD 219134         b   HD 219134 b  Radial Velocity
# 685     686   HD 219134         c   HD 219134 c  Radial Velocity
# 686     687   HD 219134         d   HD 219134 d  Radial Velocity
# 687     688   HD 219134         f   HD 219134 f  Radial Velocity
# 688     689   HD 219134         g   HD 219134 g  Radial Velocity
# 689     690   HD 219134         h   HD 219134 h  Radial Velocity
# 763     764    HD 34445         b    HD 34445 b  Radial Velocity
# 764     765    HD 34445         c    HD 34445 c  Radial Velocity
# 765     766    HD 34445         d    HD 34445 d  Radial Velocity
# 766     767    HD 34445         e    HD 34445 e  Radial Velocity
# 767     768    HD 34445         f    HD 34445 f  Radial Velocity
# 768     769    HD 34445         g    HD 34445 g  Radial Velocity
# 1392   1393     KOI-351         b     KOI-351 b          Transit
# 1393   1394     KOI-351         c     KOI-351 c          Transit
# 1394   1395     KOI-351         d     KOI-351 d          Transit
# 1395   1396     KOI-351         e     KOI-351 e          Transit
# 1396   1397     KOI-351         f     KOI-351 f          Transit
# 1397   1398     KOI-351         g     KOI-351 g          Transit
# 1398   1399     KOI-351         h     KOI-351 h          Transit
# 1546   1547   Kepler-11         b   Kepler-11 b          Transit
# 1547   1548   Kepler-11         c   Kepler-11 c          Transit
# 1548   1549   Kepler-11         d   Kepler-11 d          Transit
# 1549   1550   Kepler-11         e   Kepler-11 e          Transit
# 1550   1551   Kepler-11         f   Kepler-11 f          Transit
# 1551   1552   Kepler-11         g   Kepler-11 g          Transit
# 2372   2373   Kepler-20         b   Kepler-20 b          Transit
# 2373   2374   Kepler-20         c   Kepler-20 c          Transit
# 2374   2375   Kepler-20         d   Kepler-20 d          Transit
# 2375   2376   Kepler-20         e   Kepler-20 e          Transit
# 2376   2377   Kepler-20         f   Kepler-20 f          Transit
# 2377   2378   Kepler-20         g   Kepler-20 g  Radial Velocity
# 3468   3469   Kepler-80         b   Kepler-80 b          Transit
# 3469   3470   Kepler-80         c   Kepler-80 c          Transit
# 3470   3471   Kepler-80         d   Kepler-80 d          Transit
# 3471   3472   Kepler-80         e   Kepler-80 e          Transit
# 3472   3473   Kepler-80         f   Kepler-80 f          Transit
# 3473   3474   Kepler-80         g   Kepler-80 g          Transit
# 3603   3604     KOI-351         i   Kepler-90 i          Transit
# 3905   3906  TRAPPIST-1         b  TRAPPIST-1 b          Transit
# 3906   3907  TRAPPIST-1         c  TRAPPIST-1 c          Transit
# 3907   3908  TRAPPIST-1         d  TRAPPIST-1 d          Transit
# 3908   3909  TRAPPIST-1         e  TRAPPIST-1 e          Transit
# 3909   3910  TRAPPIST-1         f  TRAPPIST-1 f          Transit
# 3910   3911  TRAPPIST-1         g  TRAPPIST-1 g          Transit
# 3911   3912  TRAPPIST-1         h  TRAPPIST-1 h          Transit
#
#       pl_controvflag  pl_pnum    pl_orbper  pl_orbpererr1  pl_orbpererr2  ...  \
# 370                0        6     5.759690   2.800000e-04  -2.800000e-04  ...
# 371                0        6    16.357000   3.800000e-03  -3.800000e-03  ...
# 372                0        6    49.748000   2.500000e-02  -2.500000e-02  ...
# 373                0        6   122.744000   2.320000e-01  -2.320000e-01  ...
# 374                0        6   604.670000   1.042000e+01  -1.042000e+01  ...
# 375                0        6  2205.000000   1.059000e+02  -1.059000e+02  ...
# 684                0        6     3.092926   1.000000e-05  -1.000000e-05  ...
# 685                0        6     6.764580   3.300000e-04  -3.300000e-04  ...
# 686                0        6    46.859000   2.800000e-02  -2.800000e-02  ...
# 687                1        6    22.717000   1.500000e-02  -1.500000e-02  ...
# 688                0        6    94.200000   2.000000e-01  -2.000000e-01  ...
# 689                0        6  2247.000000   4.300000e+01  -4.300000e+01  ...
# 763                0        6  1049.000000   1.100000e+01  -1.100000e+01  ...
# 764                0        6   214.670000   4.500000e-01  -4.500000e-01  ...
# 765                0        6   117.870000   1.800000e-01  -1.800000e-01  ...
# 766                0        6    49.175000   4.500000e-02  -4.500000e-02  ...
# 767                0        6   676.800000   7.900000e+00  -7.900000e+00  ...
# 768                0        6  5700.000000   1.500000e+03  -1.500000e+03  ...
# 1392               0        8     7.008151   1.900000e-05  -1.900000e-05  ...
# 1393               0        8     8.719375   2.700000e-05  -2.700000e-05  ...
# 1394               0        8    59.736670   3.800000e-04  -3.800000e-04  ...
# 1395               0        8    91.939130   7.300000e-04  -7.300000e-04  ...
# 1396               0        8   124.914400   1.900000e-03  -1.900000e-03  ...
# 1397               0        8   210.606970   4.300000e-04  -4.300000e-04  ...
# 1398               0        8   331.600590   3.700000e-04  -3.700000e-04  ...
# 1546               0        6    10.303900   6.000000e-04  -1.000000e-03  ...
# 1547               0        6    13.024100   1.300000e-03  -8.000000e-04  ...
# 1548               0        6    22.684500   9.000000e-04  -9.000000e-04  ...
# 1549               0        6    31.999600   8.000000e-04  -1.200000e-03  ...
# 1550               0        6    46.688800   2.700000e-03  -3.200000e-03  ...
# 1551               0        6   118.380700   1.000000e-03  -6.000000e-04  ...
# 2372               0        6     3.696115   1.150000e-06  -8.700000e-07  ...
# 2373               0        6    10.854091   3.030000e-06  -2.600000e-06  ...
# 2374               0        6    77.611300   1.230500e-04  -1.158800e-04  ...
# 2375               0        6     6.098523   6.080000e-06  -1.351000e-05  ...
# 2376               0        6    19.577585   9.037000e-05  -1.225600e-04  ...
# 2377               0        6    34.940000   3.800000e-02  -3.500000e-02  ...
# 3468               0        6     7.052460   2.000000e-04  -2.200000e-04  ...
# 3469               0        6     9.523550   4.100000e-04  -2.900000e-04  ...
# 3470               0        6     3.072220   6.000000e-05  -4.000000e-05  ...
# 3471               0        6     4.644890   2.000000e-04  -1.900000e-04  ...
# 3472               0        6     0.986787   6.000000e-08  -6.000000e-08  ...
# 3473               0        6    14.645580   1.200000e-04  -1.200000e-04  ...
# 3603               0        8    14.449120   2.000000e-04  -2.000000e-04  ...
# 3905               0        7     1.510871   6.000000e-07  -6.000000e-07  ...
# 3906               0        7     2.421823   1.700000e-06  -1.700000e-06  ...
# 3907               0        7     4.049610   6.300000e-05  -6.300000e-05  ...
# 3908               0        7     6.099615   1.100000e-05  -1.100000e-05  ...
# 3909               0        7     9.206690   1.500000e-05  -1.500000e-05  ...
# 3910               0        7    12.352940   1.200000e-04  -1.200000e-04  ...
# 3911               0        7    18.767000   4.000000e-03  -3.000000e-03  ...
#
#       st_bmy  st_bmyerr  st_bmylim  st_m1  st_m1err  st_m1lim  st_c1  \
# 370    0.399      0.003        0.0  0.189     0.004       0.0  0.370
# 371    0.399      0.003        0.0  0.189     0.004       0.0  0.370
# 372    0.399      0.003        0.0  0.189     0.004       0.0  0.370
# 373    0.399      0.003        0.0  0.189     0.004       0.0  0.370
# 374    0.399      0.003        0.0  0.189     0.004       0.0  0.370
# 375    0.399      0.003        0.0  0.189     0.004       0.0  0.370
# 684    0.571      0.001        0.0  0.552     0.002       0.0  0.268
# 685    0.571      0.001        0.0  0.552     0.002       0.0  0.268
# 686    0.571      0.001        0.0  0.552     0.002       0.0  0.268
# 687    0.571      0.001        0.0  0.552     0.002       0.0  0.268
# 688    0.571      0.001        0.0  0.552     0.002       0.0  0.268
# 689    0.571      0.001        0.0  0.552     0.002       0.0  0.268
# 763    0.412      0.003        0.0  0.213     0.004       0.0  0.356
# 764    0.412      0.003        0.0  0.213     0.004       0.0  0.356
# 765    0.412      0.003        0.0  0.213     0.004       0.0  0.356
# 766    0.412      0.003        0.0  0.213     0.004       0.0  0.356
# 767    0.412      0.003        0.0  0.213     0.004       0.0  0.356
# 768    0.412      0.003        0.0  0.213     0.004       0.0  0.356
# 1392     NaN        NaN        NaN    NaN       NaN       NaN    NaN
# 1393     NaN        NaN        NaN    NaN       NaN       NaN    NaN
# 1394     NaN        NaN        NaN    NaN       NaN       NaN    NaN
# 1395     NaN        NaN        NaN    NaN       NaN       NaN    NaN
# 1396     NaN        NaN        NaN    NaN       NaN       NaN    NaN
# 1397     NaN        NaN        NaN    NaN       NaN       NaN    NaN
# 1398     NaN        NaN        NaN    NaN       NaN       NaN    NaN
# 1546     NaN        NaN        NaN    NaN       NaN       NaN    NaN
# 1547     NaN        NaN        NaN    NaN       NaN       NaN    NaN
# 1548     NaN        NaN        NaN    NaN       NaN       NaN    NaN
# 1549     NaN        NaN        NaN    NaN       NaN       NaN    NaN
# 1550     NaN        NaN        NaN    NaN       NaN       NaN    NaN
# 1551     NaN        NaN        NaN    NaN       NaN       NaN    NaN
# 2372     NaN        NaN        NaN    NaN       NaN       NaN    NaN
# 2373     NaN        NaN        NaN    NaN       NaN       NaN    NaN
# 2374     NaN        NaN        NaN    NaN       NaN       NaN    NaN
# 2375     NaN        NaN        NaN    NaN       NaN       NaN    NaN
# 2376     NaN        NaN        NaN    NaN       NaN       NaN    NaN
# 2377     NaN        NaN        NaN    NaN       NaN       NaN    NaN
# 3468     NaN        NaN        NaN    NaN       NaN       NaN    NaN
# 3469     NaN        NaN        NaN    NaN       NaN       NaN    NaN
# 3470     NaN        NaN        NaN    NaN       NaN       NaN    NaN
# 3471     NaN        NaN        NaN    NaN       NaN       NaN    NaN
# 3472     NaN        NaN        NaN    NaN       NaN       NaN    NaN
# 3473     NaN        NaN        NaN    NaN       NaN       NaN    NaN
# 3603     NaN        NaN        NaN    NaN       NaN       NaN    NaN
# 3905     NaN        NaN        NaN    NaN       NaN       NaN    NaN
# 3906     NaN        NaN        NaN    NaN       NaN       NaN    NaN
# 3907     NaN        NaN        NaN    NaN       NaN       NaN    NaN
# 3908     NaN        NaN        NaN    NaN       NaN       NaN    NaN
# 3909     NaN        NaN        NaN    NaN       NaN       NaN    NaN
# 3910     NaN        NaN        NaN    NaN       NaN       NaN    NaN
# 3911     NaN        NaN        NaN    NaN       NaN       NaN    NaN
#
#       st_c1err  st_c1lim  st_colorn
# 370      0.005       0.0       11.0
# 371      0.005       0.0       11.0
# 372      0.005       0.0       11.0
# 373      0.005       0.0       11.0
# 374      0.005       0.0       11.0
# 375      0.005       0.0       11.0
# 684      0.005       0.0       13.0
# 685      0.005       0.0       13.0
# 686      0.005       0.0       13.0
# 687      0.005       0.0       13.0
# 688      0.005       0.0       13.0
# 689      0.005       0.0       13.0
# 763      0.005       0.0        9.0
# 764      0.005       0.0        9.0
# 765      0.005       0.0        9.0
# 766      0.005       0.0        9.0
# 767      0.005       0.0        9.0
# 768      0.005       0.0        9.0
# 1392       NaN       NaN        5.0
# 1393       NaN       NaN        5.0
# 1394       NaN       NaN        5.0
# 1395       NaN       NaN        5.0
# 1396       NaN       NaN        5.0
# 1397       NaN       NaN        5.0
# 1398       NaN       NaN        5.0
# 1546       NaN       NaN        5.0
# 1547       NaN       NaN        5.0
# 1548       NaN       NaN        5.0
# 1549       NaN       NaN        5.0
# 1550       NaN       NaN        5.0
# 1551       NaN       NaN        5.0
# 2372       NaN       NaN        5.0
# 2373       NaN       NaN        5.0
# 2374       NaN       NaN        5.0
# 2375       NaN       NaN        5.0
# 2376       NaN       NaN        5.0
# 2377       NaN       NaN        5.0
# 3468       NaN       NaN        5.0
# 3469       NaN       NaN        5.0
# 3470       NaN       NaN        5.0
# 3471       NaN       NaN        5.0
# 3472       NaN       NaN        5.0
# 3473       NaN       NaN        5.0
# 3603       NaN       NaN        5.0
# 3905       NaN       NaN        3.0
# 3906       NaN       NaN        3.0
# 3907       NaN       NaN        3.0
# 3908       NaN       NaN        3.0
# 3909       NaN       NaN        3.0
# 3910       NaN       NaN        3.0
# 3911       NaN       NaN        3.0
#
# [51 rows x 356 columns]

# %% [markdown]
# Make new dataframe that only includes dynamical elements of interest *for each system*:

# %%
names = np.unique(multi_planets['pl_hostname'].values)
names
# Out:
# array(['HD 10180', 'HD 219134', 'HD 34445', 'KOI-351', 'Kepler-11',
#        'Kepler-20', 'Kepler-80', 'TRAPPIST-1'], dtype=object)

# %%
savedNames = []
savedSims = []

for iname,name in enumerate(names): # for each planetary system
    print('On ' + name + ' - ' + str(iname+1) + ' of ' + str(len(names)) + ' systems')
    # only select entries with this name
    mask = multi_planets['pl_hostname'] == name
    ecc = multi_planets['pl_orbeccen'][mask]
    a = multi_planets['pl_orbsmax'][mask]
    Porb = multi_planets['pl_orbper'][mask]
    Incl = multi_planets['pl_orbincl'][mask]
    sMass = multi_planets['st_mass'][mask]
    pMass = multi_planets['pl_bmassj'][mask]
    tTime = multi_planets['pl_orbtper'][mask]

    # if no incl, set to zero
    Incl[np.isnan(Incl)] = 0.0
    
    # if no tTime set to zero
    tTime[np.isnan(tTime)] = 0.0

    ecc[np.isnan(ecc)] = 0.0

    # now convert to kepler data dictionary
    # only entries we really need to use in the convert_kepler_data function
    kepler_data = {}

    mask2 = np.isnan(pMass) # check for actual masses stored
    kepler_data['SysName'] = name
    kepler_data['NumberOfPlanets'] = len(a) 
    kepler_data['Porb'] = Porb.values[~mask2]
    kepler_data['a']=a.values[~mask2]
    kepler_data['ecc']=ecc.values[~mask2]
    kepler_data['Incl']=Incl.values[~mask2]
    kepler_data['pMass']=pMass.values[~mask2]
    kepler_data['sMass']=sMass.values[~mask2]
    kepler_data['tTime']=tTime.values[~mask2]
    
    #print(len(kepler_data['pMass']))

    # calculate inputs for sims
    if len(kepler_data['pMass']) > 0:
        star_mass, \
        planet_masses, \
        planet_initial_position, \
        planet_initial_velocity, ecc = convert_kepler_data(kepler_data)
        
        # do the sim!
        # uses a hermite solution
        r_h, v_h, t_h, e_h = do_hermite(star_mass, 
                                planet_masses, 
                                planet_initial_position, 
                                planet_initial_velocity, 
                               tfinal=1e7, Nsteps=8800)
        
        # save
        #savedNames.append(name)
        #savedSims.append( (r_h, v_h, t_h, e_h) )
        saveName = "_".join(name.split()) + '-savedSim.txt'
        
        # you can save it to your local directory, or another place
        save_hermite_solution_to_file('data/' + saveName, 
                                  t_h, e_h, r_h, v_h)
        print('   saved: data/' + saveName)
# Out:
# On HD 10180 - 1 of 8 systems
#    saved: data/HD_10180_savedSim.txt
# On HD 219134 - 2 of 8 systems
#    saved: data/HD_219134_savedSim.txt
# On HD 34445 - 3 of 8 systems
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-70-e0e8f4771519> in <module>
#      52                                 planet_initial_position,
#      53                                 planet_initial_velocity,
# ---> 54                                tfinal=1e7, Nsteps=8800)
#      55
#      56         # save
#
# ~/csci-p-14110_su2020/lesson09/hermite_library.py in do_hermite(star_mass, planet_masses, planet_initial_position, planet_initial_velocity, tfinal, Nsteps, threeDee)
#     172     KE[0]  = KineticEnergy(v,m)
#     173     for i in range(1,Nsteps):
# --> 174         (r_res[:,:,i],v_res[:,:,i]) = HermiteUpdate(dt, r_res[:,:,i-1], v_res[:,:,i-1], m)
#     175         time[i] = time[i-1] + dt
#     176         Phi[i] = PotentialEnergy(r_res[:,:,i],m)
#
# ~/csci-p-14110_su2020/lesson09/hermite_library.py in HermiteUpdate(dt, r, v, m)
#      32 def HermiteUpdate(dt, r, v, m):
#      33     a = acc(r, m, 0)          # current acceleration
# ---> 34     adot = Jerks(r,v,m,0)     # current jerks
#      35     rp = r + dt*v + dt**2/2 * a + dt**3/6* adot   # predict
#      36     vp = v + dt*a + dt**2/2 * adot
#
# ~/csci-p-14110_su2020/lesson09/hermite_library.py in Jerks(r, v, m, eps)
#      27                 ra2 = ((r[i,:]-r[j,:])**2).sum() # dot product
#      28                 Je[i,:] += - ( (v[i,:]-v[j,:])/ra2**1.5  \
# ---> 29                      - 3.*(((v[i,:]-v[j,:])*(r[i,:]-r[j,:])).sum())/(ra2**2.5) *(r[i,:]-r[j,:]) )* m[j]
#      30     return Je;
#      31
#
# KeyboardInterrupt:

# %%
# Out:
# 0.08

# %%
data = {'SysName': multi_planets['pl_hostname'].values, 
        'NumberOfPlanets': multi_planets['pl_pnum'].values, 
       'Porb': multi_planets['pl_orbper'].values, 
       'a':multi_planets['pl_orbsmax'].values}

df = pd.DataFrame(data)#, columns=['SysName', 'NumberOfPlanets'])

# %%
df
# Out:
#        SysName  NumberOfPlanets         Porb        a
# 0     HD 10180                6     5.759690  0.06412
# 1     HD 10180                6    16.357000  0.12859
# 2     HD 10180                6    49.748000  0.26990
# 3     HD 10180                6   122.744000  0.49290
# 4     HD 10180                6   604.670000  1.42700
# 5     HD 10180                6  2205.000000  3.38100
# 6    HD 219134                6     3.092926  0.03876
# 7    HD 219134                6     6.764580  0.06530
# 8    HD 219134                6    46.859000  0.23700
# 9    HD 219134                6    22.717000  0.14630
# 10   HD 219134                6    94.200000  0.37530
# 11   HD 219134                6  2247.000000  3.11000
# 12    HD 34445                6  1049.000000  2.07000
# 13    HD 34445                6   214.670000  0.71810
# 14    HD 34445                6   117.870000  0.48170
# 15    HD 34445                6    49.175000  0.26870
# 16    HD 34445                6   676.800000  1.54300
# 17    HD 34445                6  5700.000000  6.36000
# 18     KOI-351                8     7.008151  0.07400
# 19     KOI-351                8     8.719375  0.08900
# 20     KOI-351                8    59.736670  0.32000
# 21     KOI-351                8    91.939130  0.42000
# 22     KOI-351                8   124.914400  0.48000
# 23     KOI-351                8   210.606970  0.71000
# 24     KOI-351                8   331.600590  1.01000
# 25   Kepler-11                6    10.303900  0.09100
# 26   Kepler-11                6    13.024100  0.10700
# 27   Kepler-11                6    22.684500  0.15500
# 28   Kepler-11                6    31.999600  0.19500
# 29   Kepler-11                6    46.688800  0.25000
# 30   Kepler-11                6   118.380700  0.46600
# 31   Kepler-20                6     3.696115  0.04630
# 32   Kepler-20                6    10.854091  0.09490
# 33   Kepler-20                6    77.611300  0.35060
# 34   Kepler-20                6     6.098523  0.06390
# 35   Kepler-20                6    19.577585  0.13960
# 36   Kepler-20                6    34.940000  0.20550
# 37   Kepler-80                6     7.052460  0.06480
# 38   Kepler-80                6     9.523550  0.07920
# 39   Kepler-80                6     3.072220  0.03720
# 40   Kepler-80                6     4.644890  0.04910
# 41   Kepler-80                6     0.986787  0.01750
# 42   Kepler-80                6    14.645580      NaN
# 43     KOI-351                8    14.449120      NaN
# 44  TRAPPIST-1                7     1.510871  0.01111
# 45  TRAPPIST-1                7     2.421823  0.01521
# 46  TRAPPIST-1                7     4.049610  0.02144
# 47  TRAPPIST-1                7     6.099615  0.02817
# 48  TRAPPIST-1                7     9.206690  0.03710
# 49  TRAPPIST-1                7    12.352940  0.04510
# 50  TRAPPIST-1                7    18.767000      NaN

# %%
df.groupby('SysName')
